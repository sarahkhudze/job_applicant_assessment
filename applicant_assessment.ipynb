# %%
pip install python-docx PyPDF2 pandas
# Out:
# ...
#   Obtaining dependency information for python-docx from https://files.pythonhosted.org/packages/3e/3d/330d9efbdb816d3f60bf2ad92f05e1708e4a1b9abe80461ac3444c83f749/python_docx-1.1.2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for PyPDF2 from https://files.pythonhosted.org/packages/8e/5e/c86a5643653825d3c913719e788e41386bee415c2b87b4f955432f2de6b2/pypdf2-3.0.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for typing-extensions>=4.9.0 from https://files.pythonhosted.org/packages/26/9f/ad63fc0248c5379346306f8668cda6e2e2e9c95e01216d2b8ffd9ff037d0/typing_extensions-4.12.2-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/244.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/244.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/244.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/244.3 kB ? eta -:--:--
# ...

# %%
import os
import re
import pandas as pd
from docx import Document
from PyPDF2 import PdfReader

# %%
# Function to extract text from .docx files
def extract_text_from_docx(file_path):
    try:
        doc = Document(file_path)
        return "\n".join([para.text for para in doc.paragraphs])
    except Exception as e:
        print(f"Error reading {file_path}: {e}")
        return ""

# Function to extract text from .pdf files
def extract_text_from_pdf(file_path):
    try:
        reader = PdfReader(file_path)
        text = ""
        for page in reader.pages:
            text += page.extract_text()
        return text
    except Exception as e:
        print(f"Error reading {file_path}: {e}")
        return ""

# Define the folder path containing the applications
folder_path = r'C:\Users\admin\Desktop\InternVacancies'  # Update with your folder path

# Define criteria keywords
criteria = {
    'diploma': r'(diploma in community development|social work|education)',
    'location': r'(Area 49|Area 25|Area 18|Mtandire|Area 47)',
    'skills': r'(Microsoft Office|email)',
    'communication': r'(communication|interpersonal skills)',
    'independence': r'(work independently|part of a team)',
    'time_management': r'(organizational skills|time management)',
    'language': r'(local languages|Chichewa)',
}

# List to store applicants and their matching scores
applicants = []

# Iterate through files in the folder
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    
    # Extract text based on file type
    if filename.endswith('.docx'):
        text_content = extract_text_from_docx(file_path)
    elif filename.endswith('.pdf'):
        text_content = extract_text_from_pdf(file_path)
    else:
        print(f"Unsupported file type for {filename}")
        continue
    
    # Check if the document contains matching criteria
    applicant_data = {'filename': filename}
    for key, pattern in criteria.items():
        match = re.search(pattern, text_content, re.IGNORECASE)
        applicant_data[key] = bool(match)
    
    applicants.append(applicant_data)

# Convert the results to a DataFrame and save as a CSV file
df = pd.DataFrame(applicants)
df.to_csv('applicant_assessment.csv', index=False)

print("Assessment complete. Results saved to 'applicant_assessment.csv'.")
# Out:
# Error reading C:\Users\admin\Desktop\InternVacancies\Application for a post as Intern.docx: Bad CRC-32 for file 'word/media/image1.png'
# Unsupported file type for Degree _03062024114421.PDF
# Unsupported file type for IMG-20240910-WA0320.jpg
# Unsupported file type for IMG_20240803_102140_741~2.jpg
# Unsupported file type for IMG_20240814_101532.jpg
# Unsupported file type for IMG_20240917_103602_18.jpg
# Unsupported file type for IMG_20240924_211007_105.jpg
# Unsupported file type for IMG_20240924_211101_851.jpg
# Unsupported file type for IMG_20240924_211121_023.jpg
# Unsupported file type for Luanar.jpeg
# Assessment complete. Results saved to 'applicant_assessment.csv'.

# %%
# Function to extract text from .docx files
def extract_text_from_docx(file_path):
    try:
        doc = Document(file_path)
        return "\n".join([para.text for para in doc.paragraphs])
    except Exception as e:
        print(f"Error reading {file_path}: {e}")
        return ""

# Function to extract text from .pdf files
def extract_text_from_pdf(file_path):
    try:
        reader = PdfReader(file_path)
        text = ""
        for page in reader.pages:
            text += page.extract_text()
        return text
    except Exception as e:
        print(f"Error reading {file_path}: {e}")
        return ""

# Define the folder path containing the applications
folder_path = r'C:\Users\admin\Desktop\InternVacancies'  # Update with your folder path

# Define criteria keywords
criteria = {
    'diploma': r'(diploma in community development|social work|education)',
    'location': r'(Area 49|Area 25|Area 18|Mtandire|Area 47)',
    'skills': r'(Microsoft Office|email)',
    'communication': r'(communication|interpersonal skills)',
    'independence': r'(work independently|part of a team)',
    'time_management': r'(organizational skills|time management)',
    'language': r'(local languages|Chichewa)',
}

# List to store applicants and their matching scores
applicants = []

# Iterate through files in the folder
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    
    # Extract text based on file type
    if filename.endswith('.docx'):
        text_content = extract_text_from_docx(file_path)
    elif filename.endswith('.pdf'):
        text_content = extract_text_from_pdf(file_path)
    else:
        print(f"Unsupported file type for {filename}")
        continue
    
    # Check if the document contains matching criteria
    applicant_data = {'filename': filename}
    for key, pattern in criteria.items():
        match = re.search(pattern, text_content, re.IGNORECASE)
        applicant_data[key] = bool(match)
    
    applicants.append(applicant_data)

# Convert the results to a DataFrame and save as a CSV file
df = pd.DataFrame(applicants)
df.to_csv('applicant_assessments.csv', index=False)

print("Assessment complete. Results saved to 'applicant_assessment.csv'.")

# %%
# Function to extract text from .docx files
def extract_text_from_docx(file_path):
    try:
        doc = Document(file_path)
        return "\n".join([para.text for para in doc.paragraphs])
    except Exception as e:
        print(f"Error reading {file_path}: {e}")
        return ""

# Function to extract text from .pdf files
def extract_text_from_pdf(file_path):
    try:
        reader = PdfReader(file_path)
        text = ""
        for page in reader.pages:
            text += page.extract_text()
        return text
    except Exception as e:
        print(f"Error reading {file_path}: {e}")
        return ""

# Define the folder path containing the applications
folder_path = r'C:\Users\admin\Desktop\applicantCV'  # Update with your folder path

# Define criteria keywords
criteria = {
    'Has Diploma (Community Development/Social Work/Education)': r'(diploma in community development|social work|education)',
    'Resides in Required Areas (Area 49/Area 25/Area 18/Mtandire/Area 47)': r'(Area 49|Area 25|Area 18|Mtandire|Area 47)',
    'Has Basic Computer Skills (Microsoft Office/Email)': r'(Microsoft Office|email)',
    'Has Excellent Communication Skills': r'(communication|interpersonal skills)',
    'Ability to Work Independently and as a Team': r'(work independently|part of a team)',
    'Has Organizational and Time Management Skills': r'(organizational skills|time management)',
    'Fluency in Local Languages (Advantage)': r'(local languages|Chichewa)',
}

# List to store applicants and their matching scores
applicants = []

# Iterate through files in the folder
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    
    # Extract text based on file type
    if filename.endswith('.docx'):
        text_content = extract_text_from_docx(file_path)
    elif filename.endswith('.pdf'):
        text_content = extract_text_from_pdf(file_path)
    else:
        print(f"Unsupported file type for {filename}")
        continue
    
    # Check if the document contains matching criteria
    applicant_data = {'Filename': filename}
    for key, pattern in criteria.items():
        match = re.search(pattern, text_content, re.IGNORECASE)
        applicant_data[key] = 'Yes' if match else 'No'
    
    applicants.append(applicant_data)

# Convert the results to a DataFrame and save as an Excel file
df = pd.DataFrame(applicants)
output_file = 'applicant_assessment.xlsx'
df.to_excel(output_file, index=False)

print(f"Assessment complete. Results saved to '{output_file}'.")
# Out:
# Assessment complete. Results saved to 'applicant_assessment.xlsx'.
